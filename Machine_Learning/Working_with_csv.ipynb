# %%
import pandas as pd

# %%
# Opening A local csv file

df=pd.read_csv('/content/college_sleep_and_gpa.csv')

# %%
# 3. Opening a csv file from an URL

import requests
from io import StringIO

url=""
headers={"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req=requests.get(url,headers=headers)
data=StringIO(req.text)

pd.read_csv(data)

# %%
pd.read_csv('/content/college_sleep_and_gpa.csv')
# Out:
#      student_id  study                  university     semester cohort_code  \
# 0           293      1  Carnegie Mellon University  Spring 2018        lac2
# 1           294      1  Carnegie Mellon University  Spring 2018        lac2
# 2           297      1  Carnegie Mellon University  Spring 2018        lac2
# 3           303      1  Carnegie Mellon University  Spring 2018        lac2
# 4           304      1  Carnegie Mellon University  Spring 2018        lac2
# ..          ...    ...                         ...          ...         ...
# 629         347      5  Carnegie Mellon University  Spring 2017        lac1
# 630         349      5  Carnegie Mellon University  Spring 2017        lac1
# 631         353      5  Carnegie Mellon University  Spring 2017        lac1
# 632         356      5  Carnegie Mellon University  Spring 2017        lac1
# 633         357      5  Carnegie Mellon University  Spring 2017        lac1
#
# ...

# %%
pd.read_csv('/content/college_sleep_and_gpa.csv',index_col='student_id')
# Out:
#             study                  university     semester cohort_code  \
# student_id
# 293             1  Carnegie Mellon University  Spring 2018        lac2
# 294             1  Carnegie Mellon University  Spring 2018        lac2
# 297             1  Carnegie Mellon University  Spring 2018        lac2
# 303             1  Carnegie Mellon University  Spring 2018        lac2
# 304             1  Carnegie Mellon University  Spring 2018        lac2
# ...           ...                         ...          ...         ...
# 347             5  Carnegie Mellon University  Spring 2017        lac1
# 349             5  Carnegie Mellon University  Spring 2017        lac1
# 353             5  Carnegie Mellon University  Spring 2017        lac1
# 356             5  Carnegie Mellon University  Spring 2017        lac1
# 357             5  Carnegie Mellon University  Spring 2017        lac1
#
#             gender  first_generation  underrepresented  avg_sleep_minutes  \
# student_id
# ...

# %%
# 7. use_cols parameter

pd.read_csv('/content/college_sleep_and_gpa.csv',usecols=['student_id','cohort_code','gender'])
# Out:
#      student_id cohort_code  gender
# 0           293        lac2  Female
# 1           294        lac2  Female
# 2           297        lac2  Female
# 3           303        lac2  Female
# 4           304        lac2  Female
# ..          ...         ...     ...
# 629         347        lac1  Female
# 630         349        lac1  Female
# 631         353        lac1  Female
# 632         356        lac1    Male
# 633         357        lac1  Female
#
# [634 rows x 3 columns]

# %%
# 8. Squeeze parametes

pd.read_csv('/content/college_sleep_and_gpa.csv',usecols=['student_id'])
# Out:
#      student_id
# 0           293
# 1           294
# 2           297
# 3           303
# 4           304
# ..          ...
# 629         347
# 630         349
# 631         353
# 632         356
# 633         357
#
# [634 rows x 1 columns]

# %%
# 9. SkipRows /nrows Parameter
pd.read_csv('/content/college_sleep_and_gpa.csv',skiprows=[0,5])
# Out:
#      293  1  Carnegie Mellon University  Spring 2018  lac2  Female  0.0  \
# 0    294  1  Carnegie Mellon University  Spring 2018  lac2  Female  0.0
# 1    297  1  Carnegie Mellon University  Spring 2018  lac2  Female  0.0
# 2    303  1  Carnegie Mellon University  Spring 2018  lac2  Female  0.0
# 3    305  1  Carnegie Mellon University  Spring 2018  lac2    Male  1.0
# 4    306  1  Carnegie Mellon University  Spring 2018  lac2    Male  0.0
# ..   ... ..                         ...          ...   ...     ...  ...
# 627  347  5  Carnegie Mellon University  Spring 2017  lac1  Female  0.0
# 628  349  5  Carnegie Mellon University  Spring 2017  lac1  Female  0.0
# 629  353  5  Carnegie Mellon University  Spring 2017  lac1  Female  0.0
# 630  356  5  Carnegie Mellon University  Spring 2017  lac1    Male  0.0
# 631  357  5  Carnegie Mellon University  Spring 2017  lac1  Female  0.0
#
#      0.0.1  370.0  6.17  ...    0.05  0.931   4.0  3.76  -0.24  49.0  0.112  \
# ...

# %%
pd.read_csv('/content/college_sleep_and_gpa.csv',nrows=100)
# Out:
#     student_id  study                  university     semester cohort_code  \
# 0          293      1  Carnegie Mellon University  Spring 2018        lac2
# 1          294      1  Carnegie Mellon University  Spring 2018        lac2
# 2          297      1  Carnegie Mellon University  Spring 2018        lac2
# 3          303      1  Carnegie Mellon University  Spring 2018        lac2
# 4          304      1  Carnegie Mellon University  Spring 2018        lac2
# ..         ...    ...                         ...          ...         ...
# 95          31      2    University of Washington  Spring 2018         uw1
# 96          32      2    University of Washington  Spring 2018         uw1
# 97          33      2    University of Washington  Spring 2018         uw1
# 98          34      2    University of Washington  Spring 2018         uw1
# 99          35      2    University of Washington  Spring 2018         uw1
#
#     gender  first_generation  underrepresented  avg_sleep_minutes  \
# ...

# %%
# dtype parameter
pd.read_csv('/content/college_sleep_and_gpa.csv',dtype={'first_generation':float })
# Out:
#      student_id  study                  university     semester cohort_code  \
# 0           293      1  Carnegie Mellon University  Spring 2018        lac2
# 1           294      1  Carnegie Mellon University  Spring 2018        lac2
# 2           297      1  Carnegie Mellon University  Spring 2018        lac2
# 3           303      1  Carnegie Mellon University  Spring 2018        lac2
# 4           304      1  Carnegie Mellon University  Spring 2018        lac2
# ..          ...    ...                         ...          ...         ...
# 629         347      5  Carnegie Mellon University  Spring 2017        lac1
# 630         349      5  Carnegie Mellon University  Spring 2017        lac1
# 631         353      5  Carnegie Mellon University  Spring 2017        lac1
# 632         356      5  Carnegie Mellon University  Spring 2017        lac1
# 633         357      5  Carnegie Mellon University  Spring 2017        lac1
#
# ...

# %%
# 13. Handling Dates
pd.read_csv('/content/college_sleep_and_gpa.csv',parse_dates=['semester']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   student_id               634 non-null    int64
#  1   study                    634 non-null    int64
#  2   university               634 non-null    object
#  3   semester                 634 non-null    object
#  4   cohort_code              634 non-null    object
#  5   gender                   631 non-null    object
#  6   first_generation         630 non-null    float64
#  7   underrepresented         633 non-null    float64
#  8   avg_sleep_minutes        634 non-null    float64
#  9   avg_sleep_hours          634 non-null    float64
#  10  daytime_sleep_minutes    634 non-null    float64
#  11  sleep_midpoint_minutes   634 non-null    float64
#  12  bedtime_variability      634 non-null    float64
#  13  nights_tracked_fraction  634 non-null    float64
# ...

# %%
# 14. Convertors

pd.read_csv('/content/college_sleep_and_gpa.csv',converters={'student_id':str}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   student_id               634 non-null    object
#  1   study                    634 non-null    int64
#  2   university               634 non-null    object
#  3   semester                 634 non-null    object
#  4   cohort_code              634 non-null    object
#  5   gender                   631 non-null    object
#  6   first_generation         630 non-null    float64
#  7   underrepresented         633 non-null    float64
#  8   avg_sleep_minutes        634 non-null    float64
#  9   avg_sleep_hours          634 non-null    float64
#  10  daytime_sleep_minutes    634 non-null    float64
#  11  sleep_midpoint_minutes   634 non-null    float64
#  12  bedtime_variability      634 non-null    float64
#  13  nights_tracked_fraction  634 non-null    float64
# ...

# %%
def rename(name):
  if name=="Carnegie Mellon University":
    return "CMU"
  else:
    return name

# %%
rename("Carnegie Mellon University")
# Out:
# 'CMU'

# %%
# Convertors

pd.read_csv('/content/college_sleep_and_gpa.csv',converters={'university':rename})
# Out:
#      student_id  study university     semester cohort_code  gender  \
# 0           293      1        CMU  Spring 2018        lac2  Female
# 1           294      1        CMU  Spring 2018        lac2  Female
# 2           297      1        CMU  Spring 2018        lac2  Female
# 3           303      1        CMU  Spring 2018        lac2  Female
# 4           304      1        CMU  Spring 2018        lac2  Female
# ..          ...    ...        ...          ...         ...     ...
# 629         347      5        CMU  Spring 2017        lac1  Female
# 630         349      5        CMU  Spring 2017        lac1  Female
# 631         353      5        CMU  Spring 2017        lac1  Female
# 632         356      5        CMU  Spring 2017        lac1    Male
# 633         357      5        CMU  Spring 2017        lac1  Female
#
#      first_generation  underrepresented  avg_sleep_minutes  avg_sleep_hours  \
# 0                 0.0               0.0              370.0             6.17
# ...

# %%
# 15. na_values parameter
pd.read_csv('/content/college_sleep_and_gpa.csv',na_values=['Male'])
# Out:
#      student_id  study                  university     semester cohort_code  \
# 0           293      1  Carnegie Mellon University  Spring 2018        lac2
# 1           294      1  Carnegie Mellon University  Spring 2018        lac2
# 2           297      1  Carnegie Mellon University  Spring 2018        lac2
# 3           303      1  Carnegie Mellon University  Spring 2018        lac2
# 4           304      1  Carnegie Mellon University  Spring 2018        lac2
# ..          ...    ...                         ...          ...         ...
# 629         347      5  Carnegie Mellon University  Spring 2017        lac1
# 630         349      5  Carnegie Mellon University  Spring 2017        lac1
# 631         353      5  Carnegie Mellon University  Spring 2017        lac1
# 632         356      5  Carnegie Mellon University  Spring 2017        lac1
# 633         357      5  Carnegie Mellon University  Spring 2017        lac1
#
# ...

# %%
# 16. Loading a huge dataset in chunks
dfs=pd.read_csv('/content/college_sleep_and_gpa.csv',chunksize=100)

# %%
for chunks in dfs:
  print(chunks.shape)
# Out:
# (100, 22)
# (100, 22)
# (100, 22)
# (100, 22)
# (34, 22)
