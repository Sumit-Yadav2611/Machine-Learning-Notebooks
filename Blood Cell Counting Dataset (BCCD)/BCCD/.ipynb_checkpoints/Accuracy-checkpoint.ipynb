# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

# %%
import yaml
from ultralytics import YOLO

import random
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import pathlib
# %matplotlib inline
from collections import Counter

# %%
with open('/content/drive/MyDrive/Dataset/data.yaml', 'r') as f:
    data_yaml = yaml.safe_load(f)

data_yaml['train'] = '/content/drive/MyDrive/Dataset/train/images'
data_yaml['val'] = '/content/drive/MyDrive/Dataset/valid/images'
data_yaml['test'] = '/content/drive/MyDrive/Dataset/test/images'

with open('data.yaml', 'w') as f:
    yaml.dump(data_yaml, f)

# %%
with open('C:\Users\MUHAMMAD NOUKHEZ\Dropbox\Noukhej-AFM\Datasets\BCCD\data.yaml', 'r') as f:
    data_yaml = yaml.safe_load(f)

data_yaml['train'] = '/content/drive/MyDrive/Dataset/train/images'
data_yaml['val'] = '/content/drive/MyDrive/Dataset/valid/images'
data_yaml['test'] = '/content/drive/MyDrive/Dataset/test/images'

with open('data.yaml', 'w') as f:
    yaml.dump(data_yaml, f)

# %%
data_yaml
# Out:
# {'train': '/content/drive/MyDrive/Dataset/train/images',
#  'val': '/content/drive/MyDrive/Dataset/valid/images',
#  'nc': 3,
#  'names': ['Platelets', 'RBC', 'WBC'],
#  'test': '/content/drive/MyDrive/Dataset/test/images'}

# %%
data_dir = Path("/content/drive/MyDrive/Dataset")
images_dir = data_dir / "train" / "images"
labels_dir = data_dir / "train" / "labels"

test_img_dir = data_dir / "test" / "images"
test_label_dir = data_dir / "test" / "labels"

class_names = data_yaml['names']

image_paths = list(images_dir.glob("*.jpg"))
label_paths = sorted(labels_dir.glob("*.txt"))

# %%
resolutions = []

for image_path in image_paths:
    img = cv2.imread(str(image_path))
    h, w, _ = img.shape
    resolutions.append((w, h))

unique_resolutions = set(resolutions)
print("Unique resolutions:", unique_resolutions)
# Out:
# Unique resolutions: {(416, 416)}

# %%
class_counts = Counter()
for label_file in label_paths:
    with open(label_file, "r") as file:
        lines = file.readlines()
    class_counts.update(Counter([int(line.split()[0]) for line in lines]))


class_counts_names = {class_names[int(class_id)]: count for class_id, count in class_counts.items()}

df = pd.DataFrame.from_dict(class_counts_names, orient="index", columns=["count"])
ax = df.plot(kind="bar")
plt.xlabel("Classes")
plt.ylabel("Number of Instances")
plt.title("Class Distribution")
plt.show()

# %%
data = []

for file in label_paths:
    with open(file) as f:
        lines = f.readlines()
        num_lines = len(lines)
        unique_values = len(set(list(map(lambda x: x.split()[0], lines))))

        data.append([file, num_lines, unique_values])

df = pd.DataFrame(data, columns=['file', 'num_lines', 'unique_values'])

# %%
df['num_lines'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='num_lines'>

# %%
df['unique_values'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='unique_values'>

# %%
num_images = 5
image_files = [f for f in pathlib.Path(images_dir).iterdir() if f.is_file()]
random.shuffle(image_files)
selected_image_files = image_files[:num_images]

for selected_image_file in selected_image_files:
    demo_image = selected_image_file
    demo_label = pathlib.Path(labels_dir) / f"{selected_image_file.stem}.txt"
    image = cv2.imread(str(demo_image))
    class_list = data_yaml['names']
    colors = [(255, 0, 0), (0, 255, 0), (0, 0, 255)]
    height, width, _ = image.shape
    T = []

    with open(demo_label, "r") as file1:
        for line in file1.readlines():
            split = line.split(" ")
            class_id = int(split[0])

            color = colors[class_id]
            clazz = class_list[class_id]

            x, y, w, h = float(split[1]), float(split[2]), float(split[3]), float(split[4])
            box = [int((x - 0.5*w)* width), int((y - 0.5*h) * height), int(w*width), int(h*height)]
            cv2.rectangle(image, box, color, 2)
            cv2.rectangle(image, (box[0], box[1] - 20), (box[0] + box[2], box[1]), color, -1)
            cv2.putText(image, class_list[class_id], (box[0], box[1] - 5), cv2.FONT_HERSHEY_SIMPLEX, .5, (0,0,0))

        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        image = cv2.resize(image, (600, 600))
        plt.show()

# %%
def test_inference(model):

    num_images = 2
    image_files = [f for f in pathlib.Path(test_img_dir).iterdir() if f.is_file()]
    random.shuffle(image_files)
    selected_image_files = image_files[:num_images]

    results = model(selected_image_files)
    i = 0
    for result in results:
        boxes = result.boxes
        masks = result.masks
        keypoints = result.keypoints
        probs = result.probs

        image_file = selected_image_files[i]
        i = i + 1
        image = cv2.imread(str(image_file))

        for b in boxes:
            xywh = b.xywh
            x = int(xywh[0][0].item())
            y = int(xywh[0][1].item())
            w = int(xywh[0][2].item())
            h = int(xywh[0][3].item())
            conf = b.conf.item()

            class_id = int(b.cls.item())
            color = colors[class_id]
            clazz = class_list[class_id]

            w2 = int(w/2)
            h2 = int(h/2)
            box = [x-w2,y-h2,w,h]

            cv2.rectangle(image, box, color, 2)

            cv2.rectangle(image, (box[0], box[1] - 20), (box[0] + box[2], box[1]), color, -1)

            cap = f'{clazz}: {conf:.2f}'
            cv2.putText(image, cap, (box[0], box[1] - 5), cv2.FONT_HERSHEY_SIMPLEX, .5, (0,0,0))


        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        plt.show()

# %%
params = {
    'data':'data.yaml',
    'imgsz':416,
    'epochs':25,
    'optimizer':'Adam',
    #'pretrained':True,
    'pretrained':False,
    'lr0':0.1,
    'lrf': 0.00001,
    'cos_lr': True
}

# %%
model_1 = YOLO('yolov8m.yaml')

# %%
results = model_1.train(**params)
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results.confusion_matrix.print()
# Out:
# 61.0 0.0 0.0 18.0
# 0.0 718.0 0.0 431.0
# 1.0 0.0 71.0 5.0
# 14.0 101.0 1.0 0.0

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/runs/detect/train/confusion_matrix.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)

# %%
image = cv2.imread("/content/runs/detect/train/F1_curve.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train/PR_curve.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train/P_curve.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train/R_curve.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train/labels.jpg")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train/labels_correlogram.jpg")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train/results.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
model_2 =  YOLO('/content/runs/detect/train/weights/best.pt')
res = model_2.val()
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25841497 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/MyDrive/Dataset/valid/labels.cache... 73 images, 0 backgrounds, 0 corrupt: 100%|██████████| 73/73 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:07<00:00,  1.50s/it]
#                    all         73        967      0.816      0.849      0.876      0.553
#              Platelets         42         76      0.838       0.75      0.847      0.405
#                    RBC         72        819      0.679       0.81      0.829      0.565
# ...

# %%
model_2 =  YOLO('/content/runs/detect/train/weights/best.pt')
test_inference(model_2)
# Out:
# 0: 416x416 1 Platelets, 17 RBCs, 1 WBC, 39.4ms
# 1: 416x416 1 Platelets, 20 RBCs, 1 WBC, 39.4ms
# Speed: 0.8ms preprocess, 39.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)

# %%
from pathlib import Path

def load_ground_truth_labels(label_dir):
    ground_truths = {}
    label_files = sorted(label_dir.glob("*.txt"))
    for label_file in label_files:
        image_id = label_file.stem
        with open(label_file, "r") as f:
            labels = [line.strip().split() for line in f.readlines()]
        ground_truths[image_id] = [(int(label[0]), float(label[1]), float(label[2]), float(label[3]), float(label[4])) for label in labels]
    return ground_truths

# Load ground truth labels
ground_truths = load_ground_truth_labels(test_label_dir)

# %%
def get_predictions(model, img_dir):
    results = model.predict(conf=0.25, source=str(img_dir))
    predictions = {}
    for result in results:
        image_id = Path(result.path).stem
        predictions[image_id] = [(int(box.cls.item()), box.conf.item(), box.xywh) for box in result.boxes]
    return predictions

# %%
# Load the model
model_2 = YOLO('/content/runs/detect/train/weights/best.pt')

# Get model predictions
predictions = get_predictions(model_2, test_img_dir)
# Out:
# image 1/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00038_jpg.rf.ffa23e4b5b55b523367f332af726eae8.jpg: 416x416 1 Platelets, 12 RBCs, 1 WBC, 22.4ms
# image 2/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00044_jpg.rf.e7760375eba4bc20c5746367e2311e18.jpg: 416x416 2 Plateletss, 10 RBCs, 2 WBCs, 22.4ms
# image 3/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00062_jpg.rf.1be1ca0ecdf783798fc10346baaa203e.jpg: 416x416 1 Platelets, 17 RBCs, 1 WBC, 22.4ms
# image 4/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00090_jpg.rf.cdbf8f6ed3b93fa902a0bc991132cb40.jpg: 416x416 1 Platelets, 12 RBCs, 1 WBC, 22.4ms
# image 5/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00099_jpg.rf.e3c42cd68359527494a53843479dff5c.jpg: 416x416 2 Plateletss, 18 RBCs, 1 WBC, 22.4ms
# image 6/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00112_jpg.rf.978cec39235980055c2ad7ff8b6f1912.jpg: 416x416 1 Platelets, 16 RBCs, 1 WBC, 18.5ms
# ...

# %%
def calculate_accuracy(predictions, ground_truths):
    correct_predictions = 0
    total_predictions = 0

    for image_id, predicted_boxes in predictions.items():
        if image_id in ground_truths:
            ground_truth_boxes = ground_truths[image_id]
            for predicted_box in predicted_boxes:
                predicted_class = predicted_box[0]
                for ground_truth_box in ground_truth_boxes:
                    ground_truth_class = ground_truth_box[0]
                    if predicted_class == ground_truth_class:
                        correct_predictions += 1
                        break
            total_predictions += len(predicted_boxes)

    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    return accuracy

# %%
def calculate_class_accuracy(predictions, ground_truths, target_class):
    correct_predictions = 0
    total_predictions = 0

    for image_id, predicted_boxes in predictions.items():
        if image_id in ground_truths:
            ground_truth_boxes = ground_truths[image_id]
            for predicted_box in predicted_boxes:
                predicted_class = predicted_box[0]
                if predicted_class == target_class:
                    total_predictions += 1
                    for ground_truth_box in ground_truth_boxes:
                        ground_truth_class = ground_truth_box[0]
                        if predicted_class == ground_truth_class:
                            correct_predictions += 1
                            break

    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    return accuracy


# Define class labels (example: 0 for RBC, 1 for WBC, 2 for Platelet)
RBC_CLASS = 0
WBC_CLASS = 1
PLATELET_CLASS = 2

# %%
# Calculate overall accuracy
overall_accuracy = calculate_accuracy(predictions, ground_truths)

# Calculate accuracy for each class
rbc_accuracy = calculate_class_accuracy(predictions, ground_truths, RBC_CLASS)
wbc_accuracy = calculate_class_accuracy(predictions, ground_truths, WBC_CLASS)
platelet_accuracy = calculate_class_accuracy(predictions, ground_truths, PLATELET_CLASS)

print(f'Overall Prediction Accuracy: {overall_accuracy:.2%}')
print(f'RBC Prediction Accuracy: {rbc_accuracy:.2%}')
print(f'WBC Prediction Accuracy: {wbc_accuracy:.2%}')
print(f'Platelet Prediction Accuracy: {platelet_accuracy:.2%}')
# Out:
# Overall Prediction Accuracy: 95.90%
# RBC Prediction Accuracy: 82.35%
# WBC Prediction Accuracy: 96.49%
# Platelet Prediction Accuracy: 97.56%

# %%
import time
from pathlib import Path
from statistics import mean

def load_ground_truth_labels(label_dir):
    ground_truths = {}
    label_files = sorted(label_dir.glob("*.txt"))
    for label_file in label_files:
        image_id = label_file.stem
        with open(label_file, "r") as f:
            labels = [line.strip().split() for line in f.readlines()]
        ground_truths[image_id] = [(int(label[0]), float(label[1]), float(label[2]), float(label[3]), float(label[4])) for label in labels]
    return ground_truths

def get_predictions(model, img_dir):
    results = model.predict(conf=0.25, source=str(img_dir))
    predictions = {}
    for result in results:
        image_id = Path(result.path).stem
        predictions[image_id] = [(int(box.cls.item()), box.conf.item(), box.xywh) for box in result.boxes]
    return predictions

def calculate_accuracy(predictions, ground_truths):
    correct_predictions = 0
    total_predictions = 0

    for image_id, predicted_boxes in predictions.items():
        if image_id in ground_truths:
            ground_truth_boxes = ground_truths[image_id]
            for predicted_box in predicted_boxes:
                predicted_class = predicted_box[0]
                for ground_truth_box in ground_truth_boxes:
                    ground_truth_class = ground_truth_box[0]
                    if predicted_class == ground_truth_class:
                        correct_predictions += 1
                        break
            total_predictions += len(predicted_boxes)

    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    return accuracy

def calculate_class_accuracy(predictions, ground_truths, target_class):
    correct_predictions = 0
    total_predictions = 0

    for image_id, predicted_boxes in predictions.items():
        if image_id in ground_truths:
            ground_truth_boxes = ground_truths[image_id]
            for predicted_box in predicted_boxes:
                predicted_class = predicted_box[0]
                if predicted_class == target_class:
                    total_predictions += 1
                    for ground_truth_box in ground_truth_boxes:
                        ground_truth_class = ground_truth_box[0]
                        if predicted_class == ground_truth_class:
                            correct_predictions += 1
                            break

    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    return accuracy

def calculate_mAP(predictions, ground_truths, iou_threshold=0.5):
    from sklearn.metrics import average_precision_score

    y_true = []
    y_scores = []

    for image_id, predicted_boxes in predictions.items():
        if image_id in ground_truths:
            ground_truth_boxes = ground_truths[image_id]
            for predicted_box in predicted_boxes:
                predicted_class = predicted_box[0]
                predicted_score = predicted_box[1]
                max_iou = 0
                for ground_truth_box in ground_truth_boxes:
                    ground_truth_class = ground_truth_box[0]
                    if predicted_class == ground_truth_class:
                        iou = calculate_iou(predicted_box[2], ground_truth_box[1:])
                        if iou > max_iou:
                            max_iou = iou
                y_true.append(1 if max_iou >= iou_threshold else 0)
                y_scores.append(predicted_score)

    mAP = average_precision_score(y_true, y_scores)
    return mAP

# %%
def calculate_iou(box1, box2):
    x1_min, y1_min = box1[0] - box1[2] / 2, box1[1] - box1[3] / 2
    x1_max, y1_max = box1[0] + box1[2] / 2, box1[1] + box1[3] / 2
    x2_min, y2_min = box2[0] - box2[2] / 2, box2[1] - box2[3] / 2
    x2_max, y2_max = box2[0] + box2[2] / 2, box2[1] + box2[3] / 2

    inter_x_min = max(x1_min, x2_min)
    inter_y_min = max(y1_min, y2_min)
    inter_x_max = min(x1_max, x2_max)
    inter_y_max = min(y1_max, y2_max)

    inter_area = max(inter_x_max - inter_x_min, 0) * max(inter_y_max - inter_y_min, 0)
    box1_area = (x1_max - x1_min) * (y1_max - y1_min)
    box2_area = (x2_max - x2_min) * (y2_max - y2_min)

    iou = inter_area / (box1_area + box2_area - inter_area)
    return iou

# Define class labels (example: 0 for RBC, 1 for WBC, 2 for Platelet)
RBC_CLASS = 0
WBC_CLASS = 1
PLATELET_CLASS = 2

# %%
# Load the model
model_2 = YOLO('/content/runs/detect/train/weights/best.pt')

# Measure execution time
start_time = time.time()

# Load ground truth labels
ground_truths = load_ground_truth_labels(test_label_dir)

# Get model predictions
predictions = get_predictions(model_2, test_img_dir)

# Calculate accuracy for each class
rbc_accuracy = calculate_class_accuracy(predictions, ground_truths, RBC_CLASS)
wbc_accuracy = calculate_class_accuracy(predictions, ground_truths, WBC_CLASS)
platelet_accuracy = calculate_class_accuracy(predictions, ground_truths, PLATELET_CLASS)

# Calculate overall accuracy
overall_accuracy = calculate_accuracy(predictions, ground_truths)
# Out:
# image 1/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00038_jpg.rf.ffa23e4b5b55b523367f332af726eae8.jpg: 416x416 1 Platelets, 12 RBCs, 1 WBC, 22.4ms
# image 2/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00044_jpg.rf.e7760375eba4bc20c5746367e2311e18.jpg: 416x416 2 Plateletss, 10 RBCs, 2 WBCs, 22.3ms
# image 3/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00062_jpg.rf.1be1ca0ecdf783798fc10346baaa203e.jpg: 416x416 1 Platelets, 17 RBCs, 1 WBC, 22.4ms
# image 4/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00090_jpg.rf.cdbf8f6ed3b93fa902a0bc991132cb40.jpg: 416x416 1 Platelets, 12 RBCs, 1 WBC, 22.3ms
# image 5/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00099_jpg.rf.e3c42cd68359527494a53843479dff5c.jpg: 416x416 2 Plateletss, 18 RBCs, 1 WBC, 16.3ms
# image 6/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00112_jpg.rf.978cec39235980055c2ad7ff8b6f1912.jpg: 416x416 1 Platelets, 16 RBCs, 1 WBC, 16.3ms
# ...

# %%
# Calculate mAP
mAP = calculate_mAP(predictions, ground_truths)

# Calculate execution time
execution_time_ms = (time.time() - start_time) * 1000

# Print results
print(f'RBC Prediction Accuracy: {rbc_accuracy:.2%}')
print(f'WBC Prediction Accuracy: {wbc_accuracy:.2%}')
print(f'Platelet Prediction Accuracy: {platelet_accuracy:.2%}')
print(f'Overall Prediction Accuracy: {overall_accuracy:.2%}')
print(f'mAP: {mAP:.2%}')
print(f'Execution Time: {execution_time_ms:.2f} ms')
# Out:
# image 1/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00038_jpg.rf.ffa23e4b5b55b523367f332af726eae8.jpg: 416x416 1 Platelets, 12 RBCs, 1 WBC, 22.4ms
# image 2/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00044_jpg.rf.e7760375eba4bc20c5746367e2311e18.jpg: 416x416 2 Plateletss, 10 RBCs, 2 WBCs, 22.3ms
# image 3/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00062_jpg.rf.1be1ca0ecdf783798fc10346baaa203e.jpg: 416x416 1 Platelets, 17 RBCs, 1 WBC, 22.4ms
# image 4/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00090_jpg.rf.cdbf8f6ed3b93fa902a0bc991132cb40.jpg: 416x416 1 Platelets, 12 RBCs, 1 WBC, 22.3ms
# image 5/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00099_jpg.rf.e3c42cd68359527494a53843479dff5c.jpg: 416x416 2 Plateletss, 18 RBCs, 1 WBC, 22.3ms
# image 6/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00112_jpg.rf.978cec39235980055c2ad7ff8b6f1912.jpg: 416x416 1 Platelets, 16 RBCs, 1 WBC, 22.3ms
# ...

# %%
params['label_smoothing'] = 0.15
model_3 =  YOLO('/content/runs/detect/train/weights/best.pt')
res=model_3.train(**params)
# Out:
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
res.confusion_matrix.print()
# Out:
# 49.0 1.0 1.0 7.0
# 0.0 741.0 9.0 346.0
# 1.0 0.0 62.0 10.0
# 26.0 77.0 0.0 0.0

# %%
image = cv2.imread("/content/runs/detect/train2/confusion_matrix.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train2/F1_curve.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train2/PR_curve.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train2/P_curve.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train2/R_curve.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train2/labels.jpg")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train2/labels_correlogram.jpg")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train2/results.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
model_4 =  YOLO('/content/runs/detect/train2/weights/best.pt')
test_inference(model_4)

# %%
# Load the model
model_4 =  YOLO('/content/runs/detect/train2/weights/best.pt')

# Get model predictions
predictions = get_predictions(model_4, test_img_dir)
# Out:
# image 1/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00038_jpg.rf.ffa23e4b5b55b523367f332af726eae8.jpg: 416x416 1 Platelets, 21 RBCs, 1 WBC, 22.3ms
# image 2/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00044_jpg.rf.e7760375eba4bc20c5746367e2311e18.jpg: 416x416 2 Plateletss, 17 RBCs, 2 WBCs, 22.3ms
# image 3/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00062_jpg.rf.1be1ca0ecdf783798fc10346baaa203e.jpg: 416x416 18 RBCs, 1 WBC, 22.3ms
# image 4/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00090_jpg.rf.cdbf8f6ed3b93fa902a0bc991132cb40.jpg: 416x416 2 Plateletss, 15 RBCs, 1 WBC, 22.3ms
# image 5/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00099_jpg.rf.e3c42cd68359527494a53843479dff5c.jpg: 416x416 1 Platelets, 22 RBCs, 1 WBC, 22.3ms
# image 6/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00112_jpg.rf.978cec39235980055c2ad7ff8b6f1912.jpg: 416x416 1 Platelets, 25 RBCs, 1 WBC, 16.3ms
# ...

# %%
# Calculate accuracy
accuracy = calculate_accuracy(predictions, ground_truths)
print(f'Prediction accuracy: {accuracy:.2%}')
# Out:
# Prediction accuracy: 95.74%

# %%
params['hsv_h'] = 0.02
params['hsv_s'] = 0.50
params['hsv_v'] = 0.30
params['degrees'] = 5.0
params['translate'] = 0.05
params['scale'] = 0.3
params['shear'] = 0.0
params['perspective'] = 0.0
params['flipud'] = 0.0
params['fliplr'] = 0.30
params['mosaic'] = 0.50
params['mixup'] = 0.0

# %%
model_5 =  YOLO('/content/runs/detect/train2/weights/best.pt')
res=model_5.train(**params)
# Out:
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
res.confusion_matrix.print()
# Out:
# 32.0 0.0 0.0 1.0
# 0.0 744.0 5.0 323.0
# 1.0 0.0 59.0 4.0
# 43.0 75.0 8.0 0.0

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/runs/detect/train3/confusion_matrix.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train3/F1_curve.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train3/PR_curve.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train3/P_curve.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train3/R_curve.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train3/labels.jpg")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train3/labels_correlogram.jpg")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
image = cv2.imread("/content/runs/detect/train3/results.png")

custom_width = 800
custom_height = 700

# Resize the image
resized_image = cv2.resize(image, (custom_width, custom_height))

cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x700>

# %%
model_5 =  YOLO('/content/runs/detect/train3/weights/best.pt')
test_inference(model_5)
# Out:
# 0: 416x416 18 RBCs, 1 WBC, 18.6ms
# 1: 416x416 20 RBCs, 1 WBC, 18.6ms
# Speed: 1.6ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 416)

# %%
# Load the model
model_6 =  YOLO('/content/runs/detect/train3/weights/best.pt')

# Get model predictions
predictions = get_predictions(model_6, test_img_dir)
# Out:
# image 1/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00038_jpg.rf.ffa23e4b5b55b523367f332af726eae8.jpg: 416x416 1 Platelets, 17 RBCs, 1 WBC, 22.4ms
# image 2/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00044_jpg.rf.e7760375eba4bc20c5746367e2311e18.jpg: 416x416 17 RBCs, 2 WBCs, 22.5ms
# image 3/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00062_jpg.rf.1be1ca0ecdf783798fc10346baaa203e.jpg: 416x416 18 RBCs, 1 WBC, 22.5ms
# image 4/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00090_jpg.rf.cdbf8f6ed3b93fa902a0bc991132cb40.jpg: 416x416 1 Platelets, 13 RBCs, 1 WBC, 22.4ms
# image 5/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00099_jpg.rf.e3c42cd68359527494a53843479dff5c.jpg: 416x416 1 Platelets, 21 RBCs, 1 WBC, 22.4ms
# image 6/36 /content/drive/MyDrive/Dataset/test/images/BloodImage_00112_jpg.rf.978cec39235980055c2ad7ff8b6f1912.jpg: 416x416 23 RBCs, 1 WBC, 22.5ms
# ...

# %%
# Calculate accuracy
accuracy = calculate_accuracy(predictions, ground_truths)
print(f'Prediction accuracy: {accuracy:.2%}')
# Out:
# Prediction accuracy: 96.10%

# %%
params['epochs'] = 200
model_7 =  YOLO('/content/runs/detect/train3/weights/best.pt')
res=model_7.train(**params)
# Out:
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
res.confusion_matrix.print()

# %%
model_12 =  YOLO('/content/runs/detect/train5/weights/best.pt')
test_inference(model_12)

# %%
# Load the model
# model_4 =  YOLO('/content/runs/detect/train2/weights/best.pt')

# Get model predictions
predictions = get_predictions(model_12, test_img_dir)

# %%
# Calculate accuracy
accuracy = calculate_accuracy(predictions, ground_truths)
print(f'Prediction accuracy: {accuracy:.2%}')

# %%
params['epochs'] = 200
model_11 =  YOLO('/content/runs/detect/train5/weights/best.pt')
res=model_11.train(**params)
# Out:
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
res.confusion_matrix.print()

# %%
model_12 =  YOLO('/content/runs/detect/train6/weights/best.pt')
test_inference(model_12)

# %%
# Get model predictions
predictions = get_predictions(model_12, test_img_dir)

# %%
# Calculate accuracy
accuracy = calculate_accuracy(predictions, ground_truths)
print(f'Prediction accuracy: {accuracy:.2%}')
